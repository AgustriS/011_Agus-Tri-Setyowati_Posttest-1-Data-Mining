# %% [markdown]
# <h1>Posttest Praktikum Sistem Informasi </h1>
#
# NIM **2109116011**
#
# NAMA **Agus Tri Setyowati**
#
# > Kerjakanlah tugas berikut berdasarkan instruksi yang diberkan. Kumpulkanlah hasil posttest ini pada Github dengan mengumpulkan link repository kalian.
#
# Disini ada dua jenis tugas.
#
# 1. Visualisasi
# 2. Penerapan Algoritma Naive Bayes
#
#
# Ketentuan pengumpulan tugas :
# 1. Kumpul Tugas ini dengan Format Kelas_NIM_Posttest 1.ipynb
# 2. Kumpulkan dalam bentuk link repository github
# 3. Berikan penjelasan untuk setiap blok kode dengan membuat text atau comment pada kodingan
# 4. Untuk bagian penjelasan gausa terlalu panjang.
# singkat padat dan jelas

# %% [markdown]
# ## Business Understanding & Data Understanding

# %% [markdown]
# Importlah pandas, seaborn, dan plotly
#
# Download dataset dari link ini [**Link Dataset**](https://github.com/fnikolas-r/Data-Mining-Course/blob/main/Pertemuan%202/ChurnBank.csv)
#
#
#
#
# Kemudian taruhlah dalam sebuah variabel bernama df
#
#
# *note: kalian dapat menambah blok yang ada*

# %%
#Import library yang diperlukan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Buatlah datasetnya disini
df =  pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# ### Business Understanding
#
# Disini kamu berandai andai bahwa kamu adalah direktur sebuah perusahaan, kamu menggunakan dataset ini dan akan menggunakan algoritma Naive Bayes untuk perkembangan perusahaan kamu. Jelaskan tujuan penggunaan dataset ini, tujuan perusahaan, serta tujuan dari penggunaan naive bayes (beri penjelasan di text ini)
#
# # **Answer:**
# 1. Tujuan penggunaan dataset ini adalah untuk melakukan analisis data mengenai profil pelanggan. Dataset ini berisi informasi tentang pelanggan bank seperti usia, jenis kelamin, tingkat pendidikan, status pernikahan, kategori penghasilan, kategori kartu kredit, dan batas kredit. Dengan memanfaatkan data ini, perusahaan dapat mempelajari perilaku pelanggan mereka dan membuat strategi bisnis yang lebih baik untuk meningkatkan keuntungan dan mengurangi kerugian.
#
# 2. Tujuan perusahaan adalah untuk meningkatkan retensi pelanggan dan mengurangi tingkat churn (atau attrition). Perusahaan ingin memahami faktor-faktor apa saja yang mempengaruhi keputusan pelanggan untuk meninggalkan bank, sehingga perusahaan dapat membuat tindakan preventif untuk mempertahankan pelanggan. Dalam hal ini, perusahaan dapat menggunakan algoritma klasifikasi seperti Naive Bayes untuk memprediksi apakah pelanggan akan tetap tinggal atau akan berpindah ke bank lain.
#
# 3. Tujuan dari penggunaan Naive Bayes adalah untuk mengklasifikasikan pelanggan menjadi dua kategori: pelanggan yang akan tetap tinggal dan pelanggan yang akan berpindah ke bank lain. Naive Bayes adalah salah satu algoritma klasifikasi yang umum digunakan dalam data mining. Algoritma ini dapat digunakan untuk mempelajari pola dari data yang sudah ada dan memprediksi kategori pelanggan berdasarkan data-data tersebut. Dengan menggunakan algoritma ini, perusahaan dapat membangun model prediksi yang dapat membantu mereka mengidentifikasi pelanggan yang berisiko dan melakukan tindakan preventif untuk mempertahankan pelanggan tersebut.

# %% [markdown]
# ### Data Understanding

# %%
# Dari dataset diatas buatlah  variabel yang berisi
# df1 isinya dataset dengan label target AttiredCustomer
# df2 dengan label bukan Attrired customer
# df3 dengan tabel untuk usia dibawah 50 tahun
# df4 untuk customer yang statusnya itu single

# Membuat variabel df1 dengan label target Attrited Customer
df1 = df[df['Attrition_Flag'] == 'Attrited Customer']

# Membuat variabel df2 dengan label bukan Attrited Customer
df2 = df[df['Attrition_Flag'] != 'Attrited Customer']

# Membuat variabel df3 untuk usia di bawah 50 tahun
df3 = df[df['Customer_Age'] < 50]

# Membuat variabel df4 untuk customer yang statusnya itu single
df4 = df[df['Marital_Status'] == 'Single']

# %%
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
# Tampilkan info dataset (df.info()) dan berikan penjelasannya dalam bentuk teks atau comment
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# # **Penjelasan:**
# 1. Dataset ini terdiri dari 20 baris dan 10 kolom.
# 2. Tidak ada kolom yang memiliki nilai null atau missing value karena setiap kolom memiliki 20 non-null count.
# 3. Tipe data dari kolom-kolomnya terdiri dari float64 (1 kolom), int64 (3 kolom), dan object (6 kolom).
# 4. Total memory usage dari dataset ini adalah 1.7+ KB.
# 5. Kolom-kolom pada dataset terdiri dari:
# - CLIENTNUM: nomor identitas unik dari masing-masing pelanggan pada bank.
# - Attrition_Flag: label target yang menunjukkan apakah pelanggan telah berhenti menggunakan layanan bank atau masih menjadi pelanggan aktif.
# - Customer_Age: usia pelanggan.
# - Gender: jenis kelamin pelanggan.
# - Education_Level: tingkat pendidikan pelanggan.
# - Marital_Status: status pernikahan pelanggan.
# - Income_Category: kategori penghasilan pelanggan.
# - Card_Category: jenis kartu kredit pelanggan.
# - Credit_Limit: batas kredit yang diberikan kepada pelanggan

# %%
#@title Opsional (nilai plus)

# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka
df.describe()
# Out:
#          Unnamed: 0     CLIENTNUM  Customer_Age  Credit_Limit
# count     20.000000  2.000000e+01     20.000000     20.000000
# mean    6105.100000  7.424893e+08     47.250000   8114.580000
# std     2850.304026  4.045524e+07      7.859791   8331.036819
# min      176.000000  7.092220e+08     32.000000   1438.300000
# 25%     4695.750000  7.120726e+08     41.000000   2502.500000
# 50%     6299.000000  7.173934e+08     47.500000   4118.500000
# 75%     8206.500000  7.822994e+08     53.500000   8621.000000
# max    10084.000000  8.098441e+08     59.000000  26792.000000

# %% [markdown]
# #### Explore Data

# %% [markdown]
# ##### Visualisasi Comparison

# %%
# Buatlah visualisasi yang menampilkan berapa banyak yang attired customer dan tidak

count_df = df['Attrition_Flag'].value_counts()
sns.barplot(x=count_df.index, y=count_df.values)
# Out:
# <AxesSubplot:>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya 
# contoh Unknown berapa dsb

sns.countplot(x='Education_Level', data=df)

# Jika ingin kategorinya terlihat bisa ganti x menjadi y
# # sns.countplot(x='Education_Level', data=df)
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %%
# Buatlah visualisasi yang menampilkan berapa banyak Education level berdasarkan gendernya
# contoh M berapa F berapa

sns.countplot(data=df, y='Education_Level', hue='Gender')

# Jika ingin kategorinya terlihat bisa ganti x menjadi y
# sns.countplot(data=df, y='Education_Level', hue='Gender')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %% [markdown]
# # **Penjelasan:**
# 1.   **Menampilkan berapa banyak yang attired customer dan tidak**: Dari visualisasi tersebut dapat dilihat bahwa jumlah customer yang masih aktif atau "Existing Customer" lebih banyak daripada jumlah customer yang sudah tidak menggunakan layanan atau "Attrited Customer". Hal ini bisa dijadikan bahan pertimbangan bagi bank dalam mengambil keputusan strategi pemasaran atau strategi lainnya untuk mempertahankan jumlah customer atau meningkatkan jumlah customer baru.
# 2.   **Menampilkan berapa banyak Education level berdasarkan kategori-kategorinya**: Dari visualisasi ini, dapat dilihat bahwa kategori dengan frekuensi tertinggi adalah Graduate, diikuti oleh High School dan Unknown. Sedangkan kategori dengan frekuensi terendah adalah Doctorate.
# 3. **Menampilkan berapa banyak Education level berdasarkan gendernya**: Dari plot tersebut dapat dilihat bahwa mayoritas pelanggan bank berpendidikan Graduate (sarjana) atau High School (SMA), sedangkan pelanggan dengan tingkat pendidikan tertinggi (Post-Graduate) dan terendah (Unknown) memiliki jumlah yang lebih sedikit. Selain itu, plot juga menunjukkan proporsi jenis kelamin dalam setiap kategori pendidikan, di mana mayoritas pelanggan bank adalah wanita di setiap tingkat pendidikan kecuali untuk kategori tingkat pendidikan "Uneducated" yang mayoritas diisi oleh pria.

# %% [markdown]
# ##### Visualisasi Distribution

# %%
# Buatlah historgram untuk customer dan credit card limit

# Membuat gambar histogram customer age dan credit card limit
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Membuat histogram customer age
sns.histplot(data=df, x='Customer_Age', ax=ax1, kde=True)
ax1.set_title('Customer Age Distribution')

# Membuat histogram credit card limit
sns.histplot(data=df, x='Credit_Limit', ax=ax2, kde=True)
ax2.set_title('Credit Card Limit Distribution')
# Out:
# Text(0.5, 1.0, 'Credit Card Limit Distribution')

# %%
# Buatlah boxplot untuk customer dan credit card limit

# Membuat boxplot untuk kolom "Customer_Age" dan "Credit_Limit"
# Buat gambar dengan dua subplot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Membuat boxplot customer age
sns.boxplot(data=df, x='Customer_Age', ax=ax1)
ax1.set_title('Customer Age Distribution')

# Membuat boxplot credit card limit
sns.boxplot(data=df, x='Credit_Limit', ax=ax2)
ax2.set_title('Credit Card Limit Distribution')
# Out:
# Text(0.5, 1.0, 'Credit Card Limit Distribution')

# %% [markdown]
# # **Penjelasan:**
# 1.  **Historgram untuk customer dan credit card limit**: Pada subplot pertama (kiri), terlihat bahwa jumlah customer terbanyak berada pada rentang usia 40-50 tahunan. Pada subplot kedua (kanan), histogram menunjukkan bahwa mayoritas pelanggan bank memiliki batas kredit di bawah 10,000, dengan beberapa pelanggan yang memiliki batas kredit di atas 20,000.
# 2.   **Boxplot untuk customer dan credit card limit**: Pada subplot pertama (ax1), boxplot menunjukkan bahwa sebagian besar pelanggan berusia antara 35-55 tahun dengan median sekitar 45 tahun. Rentang usia pelanggan berkisar antara sekitar 30 tahun hingga 60 tahun. Pada subplot kedua (ax2), boxplot menunjukkan bahwa sebagian besar pelanggan memiliki batas kredit kartu antara 2.000 hingga 15.000. Median batas kredit kartu adalah sekitar 5.000. Rentang batas kredit kartu berkisar antara sekitar 1000 hingga 35.000. Terdapat beberapa outlier pada data batas kredit kartu yang lebih dari 25.000. Terdapat beberapa data yang dianggap sebagai outlier pada distribusi batas kredit kartu, ditandai dengan titik-titik di luar whisker.

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk umur customer dan credit card limit
sns.scatterplot(x='Customer_Age', y='Credit_Limit', data=df)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# # **Penjelasan**:
# Terdapat beberapa titik yang menunjukkan outlier pada batas kredit yang sangat tinggi, meskipun mayoritas titik cenderung berkumpul di sekitar rentang batas kredit yang lebih rendah. Selain itu, tidak terlihat adanya korelasi yang kuat antara usia pelanggan dan batas kredit yang dimilikinya, namun beberapa titik menunjukkan kecenderungan bahwa semakin tua usia pelanggan maka batas kredit yang dimilikinya akan semakin tinggi.

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Buatlah pieplot untuk Income Category & Education Level

# Pie chart for Income Category
income_counts = df['Income_Category'].value_counts()
labels = income_counts.index
sizes = income_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Income Category')


# Pie chart for Education Level
edu_counts = df['Education_Level'].value_counts()
labels = edu_counts.index
sizes = edu_counts.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('Education Level')
# Out:
# Text(0.5, 1.0, 'Education Level')

# %% [markdown]
# # Penjelasan:
# 1. Pie chart menunjukkan bahwa kategori penghasilan terbanyak adalah "Less than $40k" dan kategori "60k-80k" dengan proporsi 25.0%. Kategori "Unknown" dan "80k-120k" memiliki proporsi 20.0%. Sedangkan kategori "120k+" dan "40k-60k" berada diurutan terendah dengan proporsi 5.0%.
# 2. Pie chart menunjukkan bahwa kategori tingkat pendidikan terbanyak adalah "Graduate" dan "Uneducated" dengan proporsi sebesar 25.0%, diikuti oleh kategori "High School" dengan proporsi 20.0%. Kemudian kategori "Post graduate" dan "Unknown" dengan proporsi 10.0%, dan posisi terdendah ada "Doctorate" dan "Collage" dengan proporsi 5.0%

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
sns.boxplot(data=df, x='Gender', y='Credit_Limit', hue='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Credit_Limit'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x='Attrition_Flag', y='Credit_Limit', hue='Attrition_Flag')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='Credit_Limit'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x='Attrition_Flag', y='Customer_Age', hue='Attrition_Flag')
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='Customer_Age'>

# %%
# Buatlah visualisasi countplot Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(x='Attrition_Flag', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
# mengambil hanya kolom numerik
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# menghitung korelasi antara kolom-kolom numerik
corr_matrix = df[num_cols].corr()

# membuat heatmap dari korelasi matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (intinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)

# %%
# Membuat dataframe baru 
df_baru = df.drop(['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit'], axis=1)

# %%
df_baru
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy



# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
# Membuat fungsi naive bayes
def naive_bayes(prediksi:list)-> tuple :
    attrited = df_baru[df_baru["Attrition_Flag"]=="Attrited Customer"]
    existing = df_baru[df_baru["Attrition_Flag"]!="Attrited Customer"]
    
    # probabilitas prior
    attrited_prior = len(attrited) / len(df_baru)
    existing_prior = len(existing) / len(df_baru)
    
    # likelihood
    for i in range(len(prediksi)):
        attrited_subset = attrited[attrited.iloc[:,i]==prediksi[i]]
        existing_subset = existing[existing.iloc[:,i]==prediksi[i]]
        
        attrited_posterior = (len(attrited_subset) + 1) / (len(attrited) + len(df_baru.iloc[:,i].unique()))
        existing_posterior = (len(existing_subset) + 1) / (len(existing) + len(df_baru.iloc[:,i].unique()))
        
        if i == 0:
            attrited_likelihood = attrited_posterior
            existing_likelihood = existing_posterior
        else:
            attrited_likelihood *= attrited_posterior
            existing_likelihood *= existing_posterior
    
    # probabilitas posterior
    attrited_posterior = attrited_prior * attrited_likelihood
    existing_posterior = existing_prior * existing_likelihood
    
    # menormalkan probabilitas posterior
    persentasenya = existing_posterior / (attrited_posterior + existing_posterior)
    hasilnya = "Existing Customer" if persentasenya >= 0.5 else "Attrited Customer"
    
    return (hasilnya, persentasenya)

# %%
naive_bayes(["F", "Uneducated", "Single", "Unknown","Blue"])
# Out:
# ('Attrited Customer', 0.25)
